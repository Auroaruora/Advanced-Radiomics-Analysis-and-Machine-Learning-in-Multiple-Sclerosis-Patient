# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv('GEMS_SNAPSHOT_Aurora.csv')

# %%
risk_counts = df['Risk Score (0 healthy 1 low 2 high 3 ms)'].value_counts()
plt.pie(risk_counts, labels=risk_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Risk Score Distribution')
plt.show()

# %%
# Calculating the count of each category in the 'Risk Score (0 healthy 1 low 2 high 3 ms)' column
risk_score_counts = df['Risk Score (0 healthy 1 low 2 high 3 ms)'].value_counts()

risk_score_counts
# Out:
# Risk Score (0 healthy 1 low 2 high 3 ms)
# 3.0    126
# 1.0     58
# 0.0     52
# 2.0     41
# Name: count, dtype: int64
